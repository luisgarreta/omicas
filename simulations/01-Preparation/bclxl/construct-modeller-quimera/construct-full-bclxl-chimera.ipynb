# %% [markdown]
# ## Simulation Systems
# - Tyagi2021: "Effects of Cardiolipin on the Conformational Dynamics of Membrane-Anchored Bcl-xL"
# - A model of the full-length Bcl-xL protein in a membrane-anchored configuration was constructed by combining two solution NMR structures: one lacking the C-terminal helix (PDB ID: 1LXL; residues 1–222) [29] and another of the isolated C-terminal helix (PDB ID: 6F46; helix α8, residues 209–231) [30].
# - After aligning the C-terminal helix along the Cartesian z-axis, the two structures were superimposed and joined at residue Gln-207 to generate a model for the membrane anchored full-length Bcl-xL, where the C-terminal helix is in a transmembrane orientation.
# - For each simulation, Bcl-xL was anchored into the membrane by embedding the C-terminal helix in the lipid bilayer such that the Trp-213 residue was just below the lipid phosphate groups and the soluble folded domain was within 4 Å of the membrane surface.

# %% [markdown]
# ## Protein bcl-xl (PDB 6f46)
# - Inputs: PDB file "6f46.pdb"
# - Ouputs: "6f46_model1.pdb"
#
# ![6f46_model_1](images/6f46_model1.png)

# %% [markdown]
# ## Get C-terminal helix
# - Helix α8, residues 209-231
# - Input: PDB file "6f4g_mode1.pdb"
# - Ouputs: "6f46_model1_helix8.pdb"
#
# ![6f46_model_1_helix_8](images/6f46_model1_helix8.png)

# %% [markdown]
# ### Aligning the C-terminal helix along the Cartesian z-axis
# - Input: "6f46_model1_helix8.pdb"
# - Output: "bclxl-helix8.pdb"
# - Method: VMD Script "align-zaxis-vmd.tcl"
#
# ![6f46_model_1_helix_8](images/helix8_z_aligned.png)

# %% [markdown]
# ## Construct main structure Bcl-xl lacking the C-terminal helix
# - Input: "1lxl.pdb"; residues 1-222
# - Tool: Pymol, select command
# - Outpur: "bclxl-main.pdb

# %%
from pymol import cmd
cmd.reinitialize()
cmd.load ("1lxl.pdb")
cmd.select ("sel", "resi 1:222")
cmd.save ("bclxl_MAIN.pdb", "sel")
cmd.save ("bclxl_MAIN.fasta", "sel")

# %% [markdown]
# ## Get transmembrane helix from PDB 6f46
# - Input: "6f46.pdb". Residues: 209-231
# - Output: "bclxl-TMD.pdb"

# %%
from pymol import cmd
cmd.reinitialize()
cmd.load ("6f46.pdb")
cmd.select ("sel", "resi 207-231")
cmd.save ("bclxl_TMD.pdb", "sel")
cmd.save ("bclxl_TMD.fasta", "sel")

# %% [markdown]
# ## Aligning the C-terminal helix along the Cartesian z-axis
# - Run VMD script "align_zaxis_vmd.tcl"

# %%
# !vmd -dispdev text -e align_zaxis_vmd.tcl
# Out:
# /usr/local/lib/vmd/vmd_LINUXAMD64: /lib/x86_64-linux-gnu/libGL.so.1: no version information available (required by /usr/local/lib/vmd/vmd_LINUXAMD64)
# Info) VMD for LINUXAMD64, version 1.9.4a51 (December 21, 2020)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 4 CPUs detected.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 9GB (57%)
# Info) No CUDA accelerator devices available.
# Info) Internal command editing disabled, external rlwrap in use.
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# Info) Using plugin pdb for structure file bclxl_TMD.pdb
# Info) Using plugin pdb for coordinates from file bclxl_TMD.pdb
# Info) Determining bond structure from distance search ...
# Info) Analyzing structure ...
# Info)    Atoms: 400
# Info)    Bonds: 404
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 25
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 1   Protein: 1   Nucleic: 0
# Info) Finished with coordinate file bclxl_TMD.pdb.
# 0
# atomselect0
# Info) Opened coordinate file bclxl_TMD_Z.pdb for writing.
# Info) Finished with coordinate file bclxl_TMD_Z.pdb.
# Info) VMD for LINUXAMD64, version 1.9.4a51 (December 21, 2020)
# Info) Exiting normally.
# vmd >

# %% [markdown]
# ## Constructing a model of the full-length Bcl-xl protein
# - Inputs:
#     - AA sequence (1lxl.fasta)
#     - Template1: Bcl-xL structure lacking the C-terminal helix (1lxl.pdb; residues 1-222)
#     - Template2: Bcl-xl structure of the isolated C-terminal helix (6f4f.pdb; residues 209-231)

# %%
from modeller import *
from modeller.automodel import *    # Load the AutoModel class

log.verbose()
env = Environ()

# directories for input atom files
env.io.atom_files_directory = ['.', '../atom_files']

class MyModel(AutoModel):
    def select_atoms(self):
        return Selection(self.residue_range('1:A', '206:A'),
                         self.residue_range('207:A', '231:A'))

a = MyModel(env, alnfile = 'modeller_alignment_1lxl.ali',
            knowns = ('1lxl_template','6f46_template'), sequence = '1lxl_sequence')
a.starting_model= 1
a.ending_model  = 1

a.make()
# Out:
# openf___224_> Open           $(LIB)/restyp.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/resgrp.lib
# rdresgr_266_> Number of residue groups:        2
# openf___224_> Open           ${MODINSTALL10v2}/modlib/sstruc.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     10382856   10139.508     9.902
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     10383384   10140.023     9.902
# openf___224_> Open           ${MODINSTALL10v2}/modlib/resdih.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     10431984   10187.484     9.949
# rdrdih__263_> Number of dihedral angle types         :        9
#               Maximal number of dihedral angle optima:        3
#               Dihedral angle names                   :  Alph Phi Psi Omeg chi1 chi2 chi3 chi4 chi5
# openf___224_> Open           ${MODINSTALL10v2}/modlib/radii.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     10445284   10200.473     9.961
# openf___224_> Open           ${MODINSTALL10v2}/modlib/af_mnchdef.lib
# rdwilmo_274_> Mainchain residue conformation classes:  APBLE
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch.lib
# rdclass_257_> Number of classes:        5
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch1.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch2.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch3.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/xs4.mat
# rdrrwgh_268_> Number of residue types:       21
# openf___224_> Open           modeller_alignment_1lxl.ali
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:     10474100   10228.613     9.989
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:     10489633   10243.782    10.004
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:     10505483   10259.261    10.019
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:     10537183   10290.218    10.049
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:     10600583   10352.132    10.110
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10601403   10352.933    10.110
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10601499   10353.026    10.110
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10602427   10353.933    10.111
#
# Read the alignment from file       : modeller_alignment_1lxl.ali
#
# Total number of alignment positions:   233
#
#   #  Code        #_Res #_Segm PDB_code    Name
# -------------------------------------------------------------------------------
#   1  1lxl_temp     206      1 bclxl_MAIN. Bcl-xl
#   2  6f46_temp      25      1 bclxl_TMD_Z Bcl-xl
#   3  1lxl_sequ     233      1
# check_a_343_> >> BEGINNING OF COMMAND
# openf___224_> Open           bclxl_MAIN.pdb
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10665952   10415.969    10.172
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10665952   10415.969    10.172
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10666123   10416.136    10.172
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10666973   10416.966    10.173
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10668231   10418.194    10.174
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10670135   10420.054    10.176
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10670135   10420.054    10.176
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10670225   10420.142    10.176
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10673081   10422.931    10.179
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10673081   10422.931    10.179
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10673216   10423.062    10.179
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10677500   10427.246    10.183
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10677500   10427.246    10.183
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10677698   10427.439    10.183
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10684124   10433.715    10.189
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10684124   10433.715    10.189
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10684421   10434.005    10.189
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10694043   10443.401    10.199
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10694043   10443.401    10.199
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10694493   10443.841    10.199
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10708943   10457.952    10.213
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10708943   10457.952    10.213
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10709618   10458.611    10.213
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10731276   10479.762    10.234
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     10731105   10479.595    10.234
# openf___224_> Open           bclxl_TMD_Z.pdb
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10740330   10488.604    10.243
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10740330   10488.604    10.243
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10740501   10488.771    10.243
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10741351   10489.601    10.244
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10742609   10490.829    10.245
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10744513   10492.688    10.247
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:     10744513   10492.688    10.247
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10744603   10492.776    10.247
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:     10747459   10495.565    10.250
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     10747414   10495.521    10.250
#
# check_ali___> Checking pairwise structural superpositions.
#
# Equivalent CA pairs with distance difference larger than  6.0 angstroms:
#
# ALN_POS TMPL1 TMPL2  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------------
# drmsq1__W> n<2
# drmsq3__W> n<2
# END OF TABLE
#
# check_ali___> Checking the sequence-structure alignment.
#
# Implied intrachain target CA(i)-CA(i+1) distances longer than  8.0 angstroms:
#
# ALN_POS  TMPL  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------
# END OF TABLE
# check_a_344_> << END OF COMMAND
# openf___224_> Open           ${LIB}/top_heav.lib
# read_to_681_> topology.submodel read from topology file:        3
# openf___224_> Open           ${LIB}/par.lib
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10886666   10631.510    10.382
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10888266   10633.072    10.384
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10892246   10636.959    10.388
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10894246   10638.912    10.390
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10897246   10641.842    10.392
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10901746   10646.236    10.397
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10907318   10651.678    10.402
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10910118   10654.412    10.405
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10914318   10658.514    10.409
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10920618   10664.666    10.415
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10923390   10667.373    10.417
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:     10924790   10668.740    10.419
# read_pa_232_> parameters    BONDS   ANGLS  DIHEDS IMPROPS    MODE
#                               227     561     661     112       0
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:     10961214   10704.311    10.453
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:     11143102   10881.936    10.627
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:     11170878   10909.061    10.653
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      233   1837   1880      0         0       796
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:     11249378   10985.721    10.728
#
# patch_______> segment topology patched using RTF:  1 ;  MET  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      233   1837   1880   2548      2997       796
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:     11326154   11060.697    10.801
# patch_______> segment topology patched using RTF:  233 ;  LYS  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      233   1838   1881   2550      2999       797
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      233   1838   1881   2550      2999       797
# transfe_506_> MODEL is an average of all templates.
# transfe_511_> Number of templates for coordinate transfer:        2
#               After transferring coordinates of the equivalent template atoms,
#               there are defined, undefined atoms in MODEL:     1817       21
# openf___224_> Open           1lxl_sequence.ini
# wrpdb___568_> Residues, atoms, selected atoms:      233     1838     1838
# make_re_417_> Restraint type to be calculated:  stereo
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11433603   11165.628    10.904
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11441795   11173.628    10.912
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11458179   11189.628    10.927
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11490947   11221.628    10.959
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11523715   11253.628    10.990
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11589251   11317.628    11.052
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11622019   11349.628    11.084
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11654787   11381.628    11.115
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11720323   11445.628    11.177
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11851395   11573.628    11.302
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     11916931   11637.628    11.365
# r_stere_606_> Stereochemical restraints were constructed from RTF & PRMF.
#               Added bond,angle,dihedral,improper restraints  :     1881    2550    2830     790
#               Total number of restraints before, now         :        0     8051
# make_re_422_> Number of previous, current restraints         :        0     8051
# make_re_423_> Number of previous, current selected restraints:        0     8051
# make_re_417_> Restraint type to be calculated:  phi-psi_binormal
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     12050455   11768.022    11.492
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch1.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch1.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_643_> Protein accepted:  6f46_template
# getdata_289_> Proteins (all/accepted):        2        2
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     12116027   11832.058    11.555
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     12247099   11960.058    11.680
# make_re_422_> Number of previous, current restraints         :     8051     8282
# make_re_423_> Number of previous, current selected restraints:     8051     8282
# make_re_417_> Restraint type to be calculated:  omega_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     12247099   11960.058    11.680
# openf___224_> Open           ${MODINSTALL10v2}/modlib/omega.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/omega.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_643_> Protein accepted:  6f46_template
# getdata_289_> Proteins (all/accepted):        2        2
# omgdel__425_> Unselected all O C +N +CA dihedrals:      239
#               (This is to avoid clashes between STEREO
#               and OMEGA_DIHEDRAL restraints)
# make_re_422_> Number of previous, current restraints         :     8282     8514
# make_re_423_> Number of previous, current selected restraints:     8282     8275
# make_re_417_> Restraint type to be calculated:  chi1_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     12247099   11960.058    11.680
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_643_> Protein accepted:  6f46_template
# getdata_289_> Proteins (all/accepted):        2        2
# make_re_422_> Number of previous, current restraints         :     8514     8708
# make_re_423_> Number of previous, current selected restraints:     8275     8469
# make_re_417_> Restraint type to be calculated:  chi2_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     12247099   11960.058    11.680
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi2.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_643_> Protein accepted:  6f46_template
# getdata_289_> Proteins (all/accepted):        2        2
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     12378171   12088.058    11.805
# make_re_422_> Number of previous, current restraints         :     8708     8849
# make_re_423_> Number of previous, current selected restraints:     8469     8610
# make_re_417_> Restraint type to be calculated:  chi3_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     12378171   12088.058    11.805
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi3.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_643_> Protein accepted:  6f46_template
# getdata_289_> Proteins (all/accepted):        2        2
# make_re_422_> Number of previous, current restraints         :     8849     8913
# make_re_423_> Number of previous, current selected restraints:     8610     8674
# make_re_417_> Restraint type to be calculated:  chi4_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:     12378171   12088.058    11.805
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi4.mdt
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# getdata_643_> Protein accepted:  1lxl_template
# getdata_643_> Protein accepted:  6f46_template
# getdata_289_> Proteins (all/accepted):        2        2
# make_re_422_> Number of previous, current restraints         :     8913     8933
# make_re_423_> Number of previous, current selected restraints:     8674     8694
# make_re_417_> Restraint type to be calculated:  DISTANCE
#
# Dynamically allocated memory at amaxhash_contac [B,KiB,MiB]:     12907479   12604.960    12.310
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     13169623   12860.960    12.560
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     13300695   12988.960    12.685
# make_re_422_> Number of previous, current restraints         :     8933    12248
# make_re_423_> Number of previous, current selected restraints:     8694    12009
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    12248    15708
# make_re_423_> Number of previous, current selected restraints:    12009    15469
# make_re_417_> Restraint type to be calculated:  DISTANCE
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     13562839   13244.960    12.935
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     14087127   13756.960    13.435
# make_re_422_> Number of previous, current restraints         :    15708    19379
# make_re_423_> Number of previous, current selected restraints:    15469    19140
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    19379    20916
# make_re_423_> Number of previous, current selected restraints:    19140    20677
# 0 atoms in HETATM/BLK residues constrained
# to protein atoms within 2.30 angstroms
# and protein CA atoms within 10.00 angstroms
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20916    20916
# make_re_423_> Number of previous, current selected restraints:    20677    20677
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20916    20916
# make_re_423_> Number of previous, current selected restraints:    20677    20677
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20916    20916
# make_re_423_> Number of previous, current selected restraints:    20677    20677
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20916    20916
# make_re_423_> Number of previous, current selected restraints:    20677    20677
# 0 atoms in residues without defined topology
# constrained to be rigid bodies
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20916    20916
# make_re_423_> Number of previous, current selected restraints:    20677    20677
# rmdupl__427_>     1376 redundant cosine dihedral restraints were unselected.
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:    20916    19301
# openf___224_> Open           1lxl_sequence.rsr
# openf___224_> Open           1lxl_sequence.rsr
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:     14184115   13851.675    13.527
# rdcsr2__307_> Number of restraints read    :    19301
#               Number of excluded pairs read:        0
#               Number of pseudo atoms read  :        0
# rdcsrs__304_> Restraints in memory, selected restraints:    19301    19301
#               Explicitly excluded atom pairs in memory :        0
#               Pseudo atoms in memory                   :        0
# 1817 (of 1838 total) atoms selected for optimization
# openf___224_> Open           1lxl_sequence.ini
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:     14184147   13851.706    13.527
# read_mo_297_> Segments, residues, atoms:        1      233     1838
# read_mo_298_> Segment:        1  1:A  233:A     1838
# randomi_498_> Atoms,selected atoms,random_seed,amplitude:     1838     1817        1        4.0000
# randomi_496_> Amplitude is > 0; randomization is done.
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    11671
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    13388
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    14355
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    15268
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    15731
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    15916
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    17088
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    17653
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      9903264    9671.156     9.444
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    18101
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    19232
# pick_re_612_> Number of MODEL atoms, selected restraints;     1817    19232
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      9947376    9714.234     9.487
# iupac_m_487_> NH1/2 swapped:     -177.2515        6  6
# iupac_m_486_> OE1/2 will be swapped:      158.2351        7  7
# iupac_m_485_> OD1/2 will be swapped:      115.4823       29  29
# iupac_m_486_> OE1/2 will be swapped:     -164.0774       31  31
# iupac_m_486_> OE1/2 will be swapped:      176.4394       39  39
# iupac_m_486_> OE1/2 will be swapped:      177.5002       46  46
# iupac_m_485_> OD1/2 will be swapped:      132.0145       61  61
# iupac_m_487_> NH1/2 swapped:     -179.9657       91  91
# iupac_m_487_> NH1/2 swapped:      179.9374      100  100
# iupac_m_487_> NH1/2 swapped:      179.7230      132  132
# iupac_m_485_> OD1/2 will be swapped:     -173.3835      156  156
# iupac_m_486_> OE1/2 will be swapped:     -179.8231      179  179
# iupac_m_486_> OE1/2 will be swapped:      161.8965      193  193
# iupac_m_487_> NH1/2 swapped:     -179.7413      204  204
# iupac_m_487_> NH1/2 swapped:     -163.8394      209  209
# iupac_m_487_> NH1/2 swapped:      173.0498      212  212
# iupac_m_487_> NH1/2 swapped:      180.0000      232  232
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      233
# Number of all, selected real atoms                :     1838    1817
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19301   19232
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     4985
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        3979.2249
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :    1861       3      9   0.015   0.015      111.45       1.000
#  2 Bond angle potential               :    2526      15     58   3.670   3.670      629.19       1.000
#  3 Stereochemical cosine torsion poten:    1204       0     65  49.235  49.235      446.92       1.000
#  4 Stereochemical improper torsion pot:     785       2     12   2.767   2.767      126.44       1.000
#  5 Soft-sphere overlap restraints     :    4985       7     33   0.020   0.020      238.43       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :    3315      10     56   0.431   0.431      560.28       1.000
# 10 Distance restraints 2 (N-O)        :    3460       6     76   0.508   0.508      717.23       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     0    0    1    1   13   40   63  192  215  308  267  319  365  375  354
#
#
# << end of ENERGY.
# openf___224_> Open           1lxl_sequence.B99990001.pdb
# wrpdb___568_> Residues, atoms, selected atoms:      233     1838     1838
#
# >> Summary of successfully produced models:
# Filename                          molpdf
# ----------------------------------------
# 1lxl_sequence.B99990001.pdb     3979.22485

# %%
from modeller import *
from modeller.automodel import *    # Load the AutoModel class

log.verbose()
env = Environ()

# directories for input atom files
env.io.atom_files_directory = ['.', '../atom_files']

class MyModel(AutoModel):
    def select_atoms(self):
        return Selection(self.residue_range('1:A', '206:A'))

a = MyModel(env, alnfile = 'modeller_alignment_1lxl.ali',
            knowns = ('1lxl_template','6f46_template'), sequence = '1lxl_sequence')
a.starting_model= 1
a.ending_model  = 1

a.make()
# Out:
#                          MODELLER 10.2, 2021/11/15, r12267
#
#      PROTEIN STRUCTURE MODELLING BY SATISFACTION OF SPATIAL RESTRAINTS
#
#
#                      Copyright(c) 1989-2021 Andrej Sali
#                             All Rights Reserved
#
#                              Written by A. Sali
#                                with help from
#               B. Webb, M.S. Madhusudhan, M-Y. Shen, G.Q. Dong,
#           M.A. Marti-Renom, N. Eswar, F. Alber, M. Topf, B. Oliva,
#              A. Fiser, R. Sanchez, B. Yerkovich, A. Badretdinov,
#                      F. Melo, J.P. Overington, E. Feyfant
#                  University of California, San Francisco, USA
#                     Rockefeller University, New York, USA
#                       Harvard University, Cambridge, USA
#                    Imperial Cancer Research Fund, London, UK
#               Birkbeck College, University of London, London, UK
#
#
# Kind, OS, HostName, Kernel, Processor: 4, Linux lgx 5.13.0-30-generic x86_64
# Date and time of compilation         : 2021/11/15 19:12:27
# MODELLER executable type             : x86_64-intel8
# Job starting time (YY/MM/DD HH:MM:SS): 2022/05/26 18:01:26
#
# openf___224_> Open           $(LIB)/restyp.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/resgrp.lib
# rdresgr_266_> Number of residue groups:        2
# openf___224_> Open           ${MODINSTALL10v2}/modlib/sstruc.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:       191566     187.076     0.183
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:       192094     187.592     0.183
# openf___224_> Open           ${MODINSTALL10v2}/modlib/resdih.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:       240694     235.053     0.230
# rdrdih__263_> Number of dihedral angle types         :        9
#               Maximal number of dihedral angle optima:        3
#               Dihedral angle names                   :  Alph Phi Psi Omeg chi1 chi2 chi3 chi4 chi5
# openf___224_> Open           ${MODINSTALL10v2}/modlib/radii.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:       253994     248.041     0.242
# openf___224_> Open           ${MODINSTALL10v2}/modlib/af_mnchdef.lib
# rdwilmo_274_> Mainchain residue conformation classes:  APBLE
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch.lib
# rdclass_257_> Number of classes:        5
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch1.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch2.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch3.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/xs4.mat
# rdrrwgh_268_> Number of residue types:       21
# openf___224_> Open           modeller_alignment_1lxl.ali
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:       283002     276.369     0.270
# parse_pir__E> Invalid PIR file header line: sequence:chimera
# There should be 10 fields separated by colons, :
# This line actually contains 2 fields.
# ---------------------------------------------------------------------------
# FileFormatError                           Traceback (most recent call last)
# /tmp/ipykernel_168425/3660312536.py in <module>
#      17 a.ending_model  = 1
#      18
# ---> 19 a.make()
#
# /opt/miniconda3/envs/biobb_env/lib/python3.7/site-packages/modeller/automodel/automodel.py in make(self, exit_stage)
#     139
#     140         self.outputs = []
# --> 141         self.homcsr(exit_stage)
#     142         # Exit early?
#     143         if exit_stage >= 1:
#
# /opt/miniconda3/envs/biobb_env/lib/python3.7/site-packages/modeller/automodel/automodel.py in homcsr(self, exit_stage)
#     610         """Construct the initial model and restraints"""
#     611         # Check the alignment
# --> 612         aln = self.read_alignment()
#     613
#     614         # Since in general we do not want to loose the original alignment file
#
# /opt/miniconda3/envs/biobb_env/lib/python3.7/site-packages/modeller/automodel/automodel.py in read_alignment(self, aln)
#     571             aln = Alignment(self.env)
#     572         aln.clear()
# --> 573         aln.append(file=self.alnfile, align_codes=codes)
#     574         return aln
#     575
#
# /opt/miniconda3/envs/biobb_env/lib/python3.7/site-packages/modeller/alignment.py in append(self, file, align_codes, atom_files, remove_gaps, alignment_format, io, allow_alternates)
#      80         return func(self.modpt, io.modpt, self.env.libs.modpt, align_codes,
#      81                     atom_files, fh.file_pointer, remove_gaps, alignment_format,
# ---> 82                     allow_alternates)
#      83
#      84     def read(self, **vars):
#
# FileFormatError: parse_pir__E> Invalid PIR file header line: sequence:chimera
# There should be 10 fields separated by colons, :
# This line actually contains 2 fields.

# %% [markdown]
# ## Chimera

# %%
from modeller import *
from modeller.automodel import *    # Load the AutoModel class

log.verbose()
env = Environ()

# directories for input atom files
env.io.atom_files_directory = ['.', '../atom_files']

a = AutoModel(env, 
              alnfile = 'modeller_alignment_auto.ali',
              knowns = ('1lxl_template'), sequence = '1lxl_sequence')
a.starting_model= 1
a.ending_model  = 1

a.make()
# Out:
# openf___224_> Open           $(LIB)/restyp.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/resgrp.lib
# rdresgr_266_> Number of residue groups:        2
# openf___224_> Open           ${MODINSTALL10v2}/modlib/sstruc.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      2101327    2052.077     2.004
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      2101855    2052.593     2.004
# openf___224_> Open           ${MODINSTALL10v2}/modlib/resdih.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      2150455    2100.054     2.051
# rdrdih__263_> Number of dihedral angle types         :        9
#               Maximal number of dihedral angle optima:        3
#               Dihedral angle names                   :  Alph Phi Psi Omeg chi1 chi2 chi3 chi4 chi5
# openf___224_> Open           ${MODINSTALL10v2}/modlib/radii.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      2163755    2113.042     2.064
# openf___224_> Open           ${MODINSTALL10v2}/modlib/af_mnchdef.lib
# rdwilmo_274_> Mainchain residue conformation classes:  APBLE
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch.lib
# rdclass_257_> Number of classes:        5
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch1.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch2.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch3.lib
# openf___224_> Open           ${MODINSTALL10v2}/modlib/xs4.mat
# rdrrwgh_268_> Number of residue types:       21
# openf___224_> Open           modeller_alignment_auto.ali
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      2191994    2140.619     2.090
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      2207086    2155.357     2.105
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      2222486    2170.396     2.120
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      2253286    2200.475     2.149
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      2314886    2260.631     2.208
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2315750    2261.475     2.208
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2316614    2262.318     2.209
#
# Read the alignment from file       : modeller_alignment_auto.ali
#
# Total number of alignment positions:   217
#
#   #  Code        #_Res #_Segm PDB_code    Name
# -------------------------------------------------------------------------------
#   1  1lxl_temp     217      1 bclxl_MAIN. Bcl-xl
#   2  1lxl_sequ     217      1
# check_a_343_> >> BEGINNING OF COMMAND
# openf___224_> Open           bclxl_MAIN.pdb
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2383439    2327.577     2.273
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2383439    2327.577     2.273
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2383610    2327.744     2.273
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2384460    2328.574     2.274
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2385718    2329.803     2.275
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2387622    2331.662     2.277
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2387622    2331.662     2.277
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2387712    2331.750     2.277
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2390568    2334.539     2.280
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2390568    2334.539     2.280
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2390703    2334.671     2.280
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2394987    2338.854     2.284
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2394987    2338.854     2.284
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2395185    2339.048     2.284
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2401611    2345.323     2.290
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2401611    2345.323     2.290
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2401908    2345.613     2.291
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2411530    2355.010     2.300
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2411530    2355.010     2.300
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2411980    2355.449     2.300
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2426430    2369.561     2.314
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      2426430    2369.561     2.314
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2427105    2370.220     2.315
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      2448763    2391.370     2.335
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      2448691    2391.300     2.335
#
# check_ali___> Checking the sequence-structure alignment.
#
# Implied intrachain target CA(i)-CA(i+1) distances longer than  8.0 angstroms:
#
# ALN_POS  TMPL  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------
# END OF TABLE
# check_a_344_> << END OF COMMAND
# openf___224_> Open           ${LIB}/top_heav.lib
# read_to_681_> topology.submodel read from topology file:        3
# openf___224_> Open           ${LIB}/par.lib
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2587943    2527.288     2.468
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2589543    2528.851     2.470
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2593523    2532.737     2.473
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2595523    2534.690     2.475
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2598523    2537.620     2.478
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2603023    2542.015     2.482
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2608595    2547.456     2.488
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2611395    2550.190     2.490
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2615595    2554.292     2.494
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2621895    2560.444     2.500
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2624667    2563.151     2.503
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:      2626067    2564.519     2.504
# read_pa_232_> parameters    BONDS   ANGLS  DIHEDS IMPROPS    MODE
#                               227     561     661     112       0
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:      2659979    2597.636     2.537
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:      2830793    2764.446     2.700
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:      2857209    2790.243     2.725
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      217   1724   1768      0         0       767
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:      2931173    2862.474     2.795
#
# patch_______> segment topology patched using RTF:  1 ;  MET  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      217   1724   1768   2398      2826       767
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:      3007949    2937.450     2.869
# patch_______> segment topology patched using RTF:  217 ;  HIS  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      217   1725   1769   2400      2828       768
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      217   1725   1769   2400      2828       768
# transfe_506_> MODEL is an average of all templates.
# transfe_511_> Number of templates for coordinate transfer:        1
#               After transferring coordinates of the equivalent template atoms,
#               there are defined, undefined atoms in MODEL:     1725        0
# openf___224_> Open           1lxl_sequence.ini
# wrpdb___568_> Residues, atoms, selected atoms:      217     1725     1725
# make_re_417_> Restraint type to be calculated:  stereo
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3115398    3042.381     2.971
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3123590    3050.381     2.979
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3139974    3066.381     2.995
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3172742    3098.381     3.026
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3205510    3130.381     3.057
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3271046    3194.381     3.120
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3303814    3226.381     3.151
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3336582    3258.381     3.182
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3402118    3322.381     3.245
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3533190    3450.381     3.370
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3598726    3514.381     3.432
# r_stere_606_> Stereochemical restraints were constructed from RTF & PRMF.
#               Added bond,angle,dihedral,improper restraints  :     1769    2400    2679     761
#               Total number of restraints before, now         :        0     7609
# make_re_422_> Number of previous, current restraints         :        0     7609
# make_re_423_> Number of previous, current selected restraints:        0     7609
# make_re_417_> Restraint type to be calculated:  phi-psi_binormal
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      3723464    3636.195     3.551
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch1.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/mnch1.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_289_> Proteins (all/accepted):        1        1
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3789016    3700.211     3.613
# make_re_422_> Number of previous, current restraints         :     7609     7824
# make_re_423_> Number of previous, current selected restraints:     7609     7824
# make_re_417_> Restraint type to be calculated:  omega_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      3789016    3700.211     3.613
# openf___224_> Open           ${MODINSTALL10v2}/modlib/omega.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/omega.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_289_> Proteins (all/accepted):        1        1
# omgdel__425_> Unselected all O C +N +CA dihedrals:      223
#               (This is to avoid clashes between STEREO
#               and OMEGA_DIHEDRAL restraints)
# make_re_422_> Number of previous, current restraints         :     7824     8040
# make_re_423_> Number of previous, current selected restraints:     7824     7817
# make_re_417_> Restraint type to be calculated:  chi1_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      3789016    3700.211     3.613
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_289_> Proteins (all/accepted):        1        1
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      3920088    3828.211     3.738
# make_re_422_> Number of previous, current restraints         :     8040     8222
# make_re_423_> Number of previous, current selected restraints:     7817     7999
# make_re_417_> Restraint type to be calculated:  chi2_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      3920088    3828.211     3.738
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi2.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_289_> Proteins (all/accepted):        1        1
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      4051160    3956.211     3.863
# make_re_422_> Number of previous, current restraints         :     8222     8358
# make_re_423_> Number of previous, current selected restraints:     7999     8135
# make_re_417_> Restraint type to be calculated:  chi3_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      4051160    3956.211     3.863
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi3.mdt
# getdata_643_> Protein accepted:  1lxl_template
# getdata_289_> Proteins (all/accepted):        1        1
# make_re_422_> Number of previous, current restraints         :     8358     8419
# make_re_423_> Number of previous, current selected restraints:     8135     8196
# make_re_417_> Restraint type to be calculated:  chi4_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      4051160    3956.211     3.863
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v2}/modlib/chi4.mdt
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# getdata_643_> Protein accepted:  1lxl_template
# getdata_289_> Proteins (all/accepted):        1        1
# make_re_422_> Number of previous, current restraints         :     8419     8436
# make_re_423_> Number of previous, current selected restraints:     8196     8213
# make_re_417_> Restraint type to be calculated:  DISTANCE
#
# Dynamically allocated memory at amaxhash_contac [B,KiB,MiB]:      4547924    4441.332     4.337
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      4810068    4697.332     4.587
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      4941140    4825.332     4.712
# make_re_422_> Number of previous, current restraints         :     8436    11670
# make_re_423_> Number of previous, current selected restraints:     8213    11447
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    11670    15005
# make_re_423_> Number of previous, current selected restraints:    11447    14782
# make_re_417_> Restraint type to be calculated:  DISTANCE
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      5203284    5081.332     4.962
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      5727572    5593.332     5.462
# make_re_422_> Number of previous, current restraints         :    15005    18693
# make_re_423_> Number of previous, current selected restraints:    14782    18470
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    18693    20270
# make_re_423_> Number of previous, current selected restraints:    18470    20047
# 0 atoms in HETATM/BLK residues constrained
# to protein atoms within 2.30 angstroms
# and protein CA atoms within 10.00 angstroms
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20270    20270
# make_re_423_> Number of previous, current selected restraints:    20047    20047
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20270    20270
# make_re_423_> Number of previous, current selected restraints:    20047    20047
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20270    20270
# make_re_423_> Number of previous, current selected restraints:    20047    20047
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20270    20270
# make_re_423_> Number of previous, current selected restraints:    20047    20047
# 0 atoms in residues without defined topology
# constrained to be rigid bodies
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :    20270    20270
# make_re_423_> Number of previous, current selected restraints:    20047    20047
# rmdupl__427_>     1296 redundant cosine dihedral restraints were unselected.
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:    20270    18751
# openf___224_> Open           1lxl_sequence.rsr
# openf___224_> Open           1lxl_sequence.rsr
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      5850560    5713.438     5.580
# rdcsr2__307_> Number of restraints read    :    18751
#               Number of excluded pairs read:        0
#               Number of pseudo atoms read  :        0
# rdcsrs__304_> Restraints in memory, selected restraints:    18751    18751
#               Explicitly excluded atom pairs in memory :        0
#               Pseudo atoms in memory                   :        0
# openf___224_> Open           1lxl_sequence.ini
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:      5850592    5713.469     5.580
# read_mo_297_> Segments, residues, atoms:        1      217     1725
# read_mo_298_> Segment:        1  1:A  217:A     1725
# randomi_498_> Atoms,selected atoms,random_seed,amplitude:     1725     1725        1        4.0000
# randomi_496_> Amplitude is > 0; randomization is done.
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    11337
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    13006
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    13928
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    14788
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    15250
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    15435
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    16607
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    17172
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:      6184564    6039.613     5.898
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    17620
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    18751
# pick_re_612_> Number of MODEL atoms, selected restraints;     1725    18751
# iupac_m_487_> NH1/2 swapped:      179.8673        6  6
# iupac_m_483_> CD1/2 CE1/2 swapped:       90.4655       15  15
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_484W> Dihedral still outside +-90:      -90.7913
# iupac_m_485_> OD1/2 will be swapped:      -93.2628       29  29
# iupac_m_486_> OE1/2 will be swapped:      110.4213       46  46
# iupac_m_485_> OD1/2 will be swapped:      120.6120       61  61
# iupac_m_486_> OE1/2 will be swapped:      173.0335       92  92
# iupac_m_487_> NH1/2 swapped:      178.8416      100  100
# iupac_m_487_> NH1/2 swapped:     -178.9385      102  102
# iupac_m_487_> NH1/2 swapped:      177.2755      103  103
# iupac_m_485_> OD1/2 will be swapped:     -139.2119      156  156
# iupac_m_486_> OE1/2 will be swapped:     -106.9564      202  202
# iupac_m_487_> NH1/2 swapped:      178.7747      204  204
# iupac_m_486_> OE1/2 will be swapped:     -124.2195      208  208
# iupac_m_487_> NH1/2 swapped:     -179.9604      209  209
# iupac_m_486_> OE1/2 will be swapped:      178.9382      211  211
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      217
# Number of all, selected real atoms                :     1725    1725
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    18751   18751
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     3581
# Dynamic pairs routine                             : 2, NATM x NATM cell sorting
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        2152.4321
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :    1769       0      0   0.006   0.006      15.446       1.000
#  2 Bond angle potential               :    2400       1     10   2.222   2.222      234.55       1.000
#  3 Stereochemical cosine torsion poten:    1160       0     61  49.278  49.278      423.14       1.000
#  4 Stereochemical improper torsion pot:     761       0      1   1.332   1.332      34.756       1.000
#  5 Soft-sphere overlap restraints     :    3581       0      0   0.003   0.003      3.7025       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :    3234       3     17   0.260   0.260      222.76       1.000
# 10 Distance restraints 2 (N-O)        :    3335       2     38   0.376   0.376      409.25       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:     216       2      4   5.153   5.153      67.628       1.000
# 14 Sidechain Chi_1 dihedral restraints:     182       0      7  55.116  55.116      53.394       1.000
# 15 Sidechain Chi_2 dihedral restraints:     136       0      3  71.062  71.062      54.511       1.000
# 16 Sidechain Chi_3 dihedral restraints:      61       0      0  59.823  59.823      43.847       1.000
# 17 Sidechain Chi_4 dihedral restraints:      17       0      0 113.299 113.299      12.800       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :